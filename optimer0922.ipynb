# %%
import polars as pl
import polars.selectors as cs
import pandas as pd
import gc

# %%
train_df = pl.read_csv("/Users/brendan/Desktop - Brendan’s MacBook Air/kaggle/optiver-trading-at-the-close/train.csv")
train_df_pandas = pd.read_csv('/Users/brendan/Desktop - Brendan’s MacBook Air/kaggle/optiver-trading-at-the-close/train.csv')



revealed_targets = pl.read_csv('/Users/brendan/Desktop - Brendan’s MacBook Air/kaggle/optiver-trading-at-the-close/example_test_files/revealed_targets.csv')

# %%
test_df = pl.read_csv('/Users/brendan/Desktop - Brendan’s MacBook Air/kaggle/optiver-trading-at-the-close/example_test_files/test.csv')
test_df_pandas = pd.read_csv('/Users/brendan/Desktop - Brendan’s MacBook Air/kaggle/optiver-trading-at-the-close/example_test_files/test.csv')

# %%
train_df.head()
# Out:
# shape: (5, 17)
# ┌──────────┬─────────┬───────────────────┬────────────────┬───┬─────┬───────────┬─────────┬────────┐
# │ stock_id ┆ date_id ┆ seconds_in_bucket ┆ imbalance_size ┆ … ┆ wap ┆ target    ┆ time_id ┆ row_id │
# │ ---      ┆ ---     ┆ ---               ┆ ---            ┆   ┆ --- ┆ ---       ┆ ---     ┆ ---    │
# │ i64      ┆ i64     ┆ i64               ┆ f64            ┆   ┆ f64 ┆ f64       ┆ i64     ┆ str    │
# ╞══════════╪═════════╪═══════════════════╪════════════════╪═══╪═════╪═══════════╪═════════╪════════╡
# │ 0        ┆ 0       ┆ 0                 ┆ 3.1806e6       ┆ … ┆ 1.0 ┆ -3.029704 ┆ 0       ┆ 0_0_0  │
# │ 1        ┆ 0       ┆ 0                 ┆ 166603.91      ┆ … ┆ 1.0 ┆ -5.519986 ┆ 0       ┆ 0_0_1  │
# │ 2        ┆ 0       ┆ 0                 ┆ 302879.87      ┆ … ┆ 1.0 ┆ -8.38995  ┆ 0       ┆ 0_0_2  │
# │ 3        ┆ 0       ┆ 0                 ┆ 1.1918e7       ┆ … ┆ 1.0 ┆ -4.0102   ┆ 0       ┆ 0_0_3  │
# ...

# %%
collected_objects = gc.collect()

# %%
train_df.head()
# Out:
# shape: (5, 17)
# ┌──────────┬─────────┬───────────────────┬────────────────┬───┬─────┬───────────┬─────────┬────────┐
# │ stock_id ┆ date_id ┆ seconds_in_bucket ┆ imbalance_size ┆ … ┆ wap ┆ target    ┆ time_id ┆ row_id │
# │ ---      ┆ ---     ┆ ---               ┆ ---            ┆   ┆ --- ┆ ---       ┆ ---     ┆ ---    │
# │ i64      ┆ i64     ┆ i64               ┆ f64            ┆   ┆ f64 ┆ f64       ┆ i64     ┆ str    │
# ╞══════════╪═════════╪═══════════════════╪════════════════╪═══╪═════╪═══════════╪═════════╪════════╡
# │ 0        ┆ 0       ┆ 0                 ┆ 3.1806e6       ┆ … ┆ 1.0 ┆ -3.029704 ┆ 0       ┆ 0_0_0  │
# │ 1        ┆ 0       ┆ 0                 ┆ 166603.91      ┆ … ┆ 1.0 ┆ -5.519986 ┆ 0       ┆ 0_0_1  │
# │ 2        ┆ 0       ┆ 0                 ┆ 302879.87      ┆ … ┆ 1.0 ┆ -8.38995  ┆ 0       ┆ 0_0_2  │
# │ 3        ┆ 0       ┆ 0                 ┆ 1.1918e7       ┆ … ┆ 1.0 ┆ -4.0102   ┆ 0       ┆ 0_0_3  │
# ...

# %%
train_df.approx_n_unique()
# Out:
# shape: (1, 17)
# ┌──────────┬─────────┬───────────────────┬────────────────┬───┬───────┬────────┬─────────┬─────────┐
# │ stock_id ┆ date_id ┆ seconds_in_bucket ┆ imbalance_size ┆ … ┆ wap   ┆ target ┆ time_id ┆ row_id  │
# │ ---      ┆ ---     ┆ ---               ┆ ---            ┆   ┆ ---   ┆ ---    ┆ ---     ┆ ---     │
# │ u32      ┆ u32     ┆ u32               ┆ u32            ┆   ┆ u32   ┆ u32    ┆ u32     ┆ u32     │
# ╞══════════╪═════════╪═══════════════════╪════════════════╪═══╪═══════╪════════╪═════════╪═════════╡
# │ 198      ┆ 482     ┆ 55                ┆ 3004545        ┆ … ┆ 31403 ┆ 15749  ┆ 26653   ┆ 5300724 │
# └──────────┴─────────┴───────────────────┴────────────────┴───┴───────┴────────┴─────────┴─────────┘

# %%
desc = pd.DataFrame(index=list(train_df_pandas))
desc['count'] = train_df_pandas.count()
desc['nunique']= train_df_pandas.nunique()
desc['%_unique'] = desc['nunique']/len(train_df_pandas)*100
desc['null'] = train_df_pandas.isnull().sum()
desc['type']= train_df_pandas.dtypes
desc = pd.concat([desc, train_df_pandas.describe().T],axis=1)

# %%
desc
# Out:
#                            count  nunique    %_unique     null     type  \
# stock_id                 5237980      200    0.003818        0    int64
# date_id                  5237980      481    0.009183        0    int64
# seconds_in_bucket        5237980       55    0.001050        0    int64
# imbalance_size           5237760  2971863   56.736815      220  float64
# imbalance_buy_sell_flag  5237980        3    0.000057        0    int64
# reference_price          5237760    28741    0.548704      220  float64
# matched_size             5237760  2948862   56.297695      220  float64
# far_price                2343638    95739    1.827785  2894342  float64
# near_price               2380800    84625    1.615604  2857180  float64
# bid_price                5237760    28313    0.540533      220  float64
# bid_size                 5237980  2591773   49.480391        0  float64
# ask_price                5237760    28266    0.539636      220  float64
# ...

# %%
test_df.head()
# Out:
# shape: (3, 16)
# ┌──────────┬─────────┬───────────────────┬────────────────┬───┬──────────┬─────┬─────────┬─────────┐
# │ stock_id ┆ date_id ┆ seconds_in_bucket ┆ imbalance_size ┆ … ┆ ask_size ┆ wap ┆ time_id ┆ row_id  │
# │ ---      ┆ ---     ┆ ---               ┆ ---            ┆   ┆ ---      ┆ --- ┆ ---     ┆ ---     │
# │ i64      ┆ i64     ┆ i64               ┆ f64            ┆   ┆ f64      ┆ f64 ┆ i64     ┆ str     │
# ╞══════════╪═════════╪═══════════════════╪════════════════╪═══╪══════════╪═════╪═════════╪═════════╡
# │ 0        ┆ 481     ┆ 0                 ┆ 5.4980e6       ┆ … ┆ 28315.0  ┆ 1.0 ┆ 26455   ┆ 481_0_0 │
# │ 1        ┆ 481     ┆ 0                 ┆ 0.0            ┆ … ┆ 17651.95 ┆ 1.0 ┆ 26455   ┆ 481_0_1 │
# │ 2        ┆ 481     ┆ 0                 ┆ 5439944.9      ┆ … ┆ 116259.6 ┆ 1.0 ┆ 26455   ┆ 481_0_2 │
# └──────────┴─────────┴───────────────────┴────────────────┴───┴──────────┴─────┴─────────┴─────────┘

# %%
desc_test = pd.DataFrame(index=list(test_df_pandas))
desc_test['count'] = test_df_pandas.count()
desc_test['nunique']= test_df_pandas.nunique()
desc_test['%_unique'] = desc['nunique']/len(test_df_pandas)*100
desc_test['null'] = test_df_pandas.isnull().sum()
desc_test['type']= test_df_pandas.dtypes
desc_test = pd.concat([desc_test, test_df_pandas.describe().T],axis=1)

# %%
desc_test.head()
# Out:
#                          count  nunique      %_unique  null     type  count  \
# stock_id                     3        3  6.666667e+03     0    int64    3.0
# date_id                      3        1  1.603333e+04     0    int64    3.0
# seconds_in_bucket            3        1  1.833333e+03     0    int64    3.0
# imbalance_size               3        3  9.906210e+07     0  float64    3.0
# imbalance_buy_sell_flag      3        2  1.000000e+02     0    int64    3.0
#
#                                  mean           std    min         25%  \
# stock_id                 1.000000e+00  1.000000e+00    0.0        0.50
# date_id                  4.810000e+02  0.000000e+00  481.0      481.00
# seconds_in_bucket        0.000000e+00  0.000000e+00    0.0        0.00
# imbalance_size           3.645970e+06  3.157636e+06    0.0  2719972.45
# imbalance_buy_sell_flag -6.666667e-01  5.773503e-01   -1.0       -1.00
#
#                                50%         75%         max
# ...

# %%
train_df_pandas.head()
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0        0                  0      3180602.69
# 1         1        0                  0       166603.91
# 2         2        0                  0       302879.87
# 3         3        0                  0     11917682.27
# 4         4        0                  0       447549.96
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.999812   13380276.64        NaN
# 1                       -1         0.999896    1642214.25        NaN
# 2                       -1         0.999561    1819368.03        NaN
# 3                       -1         1.000171   18389745.62        NaN
# 4                       -1         0.999532   17860614.95        NaN
#
#    near_price  bid_price  bid_size  ask_price   ask_size  wap    target  \
# 0         NaN   0.999812  60651.50   1.000026    8493.03  1.0 -3.029704
# ...

# %%
train_df_pandas[train_df_pandas['stock_id']==1]
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 1               1        0                  0       166603.91
# 192             1        0                 10       165923.20
# 383             1        0                 20       165923.20
# 574             1        0                 30       165923.20
# 765             1        0                 40       162349.47
# ...           ...      ...                ...             ...
# 5236981         1      480                500        88468.41
# 5237181         1      480                510       310778.50
# 5237381         1      480                520       310778.50
# 5237581         1      480                530       310778.50
# 5237781         1      480                540        43854.51
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 1                             -1         0.999896    1642214.25        NaN
# ...

# %%
train_df_pandas['stock_id'].nunique()
# Out:
# 200

# %%
train_df.approx_n_unique()
# Out:
# shape: (1, 17)
# ┌──────────┬─────────┬───────────────────┬────────────────┬───┬───────┬────────┬─────────┬─────────┐
# │ stock_id ┆ date_id ┆ seconds_in_bucket ┆ imbalance_size ┆ … ┆ wap   ┆ target ┆ time_id ┆ row_id  │
# │ ---      ┆ ---     ┆ ---               ┆ ---            ┆   ┆ ---   ┆ ---    ┆ ---     ┆ ---     │
# │ u32      ┆ u32     ┆ u32               ┆ u32            ┆   ┆ u32   ┆ u32    ┆ u32     ┆ u32     │
# ╞══════════╪═════════╪═══════════════════╪════════════════╪═══╪═══════╪════════╪═════════╪═════════╡
# │ 198      ┆ 482     ┆ 55                ┆ 3004545        ┆ … ┆ 31403 ┆ 15749  ┆ 26653   ┆ 5300724 │
# └──────────┴─────────┴───────────────────┴────────────────┴───┴───────┴────────┴─────────┴─────────┘

# %%
train_df_pandas.columns
# Out:
# Index(['stock_id', 'date_id', 'seconds_in_bucket', 'imbalance_size',
#        'imbalance_buy_sell_flag', 'reference_price', 'matched_size',
#        'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price',
#        'ask_size', 'wap', 'target', 'time_id', 'row_id'],
#       dtype='object')

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense

model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(input_shape)))
model.add(GRU(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
